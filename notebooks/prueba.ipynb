# %%
import pandas as pd

# %%
df_exportaciones = pd.read_csv('../data/Exportaciones.csv')

# %%
df_exportaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97080 entries, 0 to 97079
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Periodo                            97080 non-null  int64
#  1   Año                                97080 non-null  int64
#  2   Trimestres                         97080 non-null  object
#  3   Matricero                          97080 non-null  object
#  4   Código Matricero                   97080 non-null  int64
#  5   Valor Peso Neto en miles           97080 non-null  object
#  6   Año - Mes                          97080 non-null  object
#  7   Mes                                97080 non-null  object
#  8   Num Mes                            97080 non-null  int64
#  9   Trimestre                          97080 non-null  object
#  10  País Procedencia / Destino         97080 non-null  object
# ...

# %%
print(list(df_exportaciones['País Procedencia / Destino'].unique()))
# Out:
# ['ALEMANIA', 'AUSTRIA', 'BELARÚS', 'CANADÁ', 'CHINA', 'COLOMBIA', 'ESPAÑA', 'ESTADOS UNIDOS', 'FRANCIA', 'GEORGIA', 'HONG KONG', 'ITALIA', 'JAPÓN', 'KAZAJISTAN', 'KUWAIT', 'PAÍSES BAJOS (HOLANDA)', 'PORTUGAL', 'QATAR', 'REPÚBLICA CHECA', 'RUMANIA', 'RUSIA', 'SUIZA', 'UCRANIA', 'VIETNAM', 'EL SALVADOR', 'PARAGUAY', 'REPÚBLICA DOMINICANA', 'ARABIA SAUDITA', 'BAHRÉIN', 'CHILE', 'EMIRATOS ÁRABES UNIDOS', 'ESLOVAQUIA', 'JAMAICA', 'LITUANIA', 'NICARAGUA', 'ARGENTINA', 'BOSNIA Y HERZEGOVINA', 'ESLOVENIA', 'ESTONIA', 'INDONESIA', 'POLONIA', 'TRINIDAD Y TOBAGO', 'AZERBAIYÁN', 'COREA (SUR), REPÚBLICA DE', 'CROACIA', 'FILIPINAS', 'MALTA', 'PUERTO RICO', 'REINO UNIDO', 'SINGAPUR', 'HONDURAS', 'PERÚ', 'SERBIA', 'BRASIL', 'KIRGUISTÁN', 'MACEDONIA', 'MOLDOVA, REPÚBLICA DE', 'SUECIA', 'TAYIKISTÁN', 'URUGUAY', 'BAHAMAS', 'LETONIA', 'AUSTRALIA', 'BÉLGICA', 'MARRUECOS', 'NORUEGA', 'UZBEKISTÁN', 'GUADALUPE', 'JORDANIA', 'MALASIA', 'MARTINICA', 'TAILANDIA', 'GUATEMALA', 'MALDIVAS', 'SAINT KITTS Y NEVIS (
# ...

# %%
df_festividades = pd.read_csv('../data/festividades.csv')
df_festividades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pais        138 non-null    object
#  1   festividad  138 non-null    object
#  2   mes         138 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.4+ KB

# %%
df_IPC = pd.read_csv('../data/IPC.csv')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16784\32646021.py:1: DtypeWarning: Columns (8,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_IPC = pd.read_csv('../data/IPC.csv')

# %%
df_IPC[df_IPC['TYPE_OF_TRANSFORMATION'] == 'Index']
# Out:
#                   DATASET         SERIES_CODE OBS_MEASURE COUNTRY  \
# 1      IMF.STA:CPI(4.0.0)   KWT.CPI.CP03.IX.Q   OBS_VALUE  Kuwait
# 5      IMF.STA:CPI(4.0.0)   KWT.CPI.CP03.IX.M   OBS_VALUE  Kuwait
# 6      IMF.STA:CPI(4.0.0)   KWT.CPI.CP08.IX.Q   OBS_VALUE  Kuwait
# 8      IMF.STA:CPI(4.0.0)   KWT.CPI.CP02.IX.M   OBS_VALUE  Kuwait
# 11     IMF.STA:CPI(4.0.0)   KWT.CPI.CP10.IX.M   OBS_VALUE  Kuwait
# ...                   ...                 ...         ...     ...
# 30518  IMF.STA:CPI(4.0.0)  ESP.HICP.CP08.IX.A   OBS_VALUE   Spain
# 30521  IMF.STA:CPI(4.0.0)  ESP.HICP.CP03.IX.Q   OBS_VALUE   Spain
# 30525  IMF.STA:CPI(4.0.0)  ESP.HICP.CP03.IX.A   OBS_VALUE   Spain
# 30549  IMF.STA:CPI(4.0.0)  FRA.HICP.CP07.IX.A   OBS_VALUE  France
# 30553  IMF.STA:CPI(4.0.0)    ESP.HICP._T.IX.A   OBS_VALUE   Spain
#
#                                        INDEX_TYPE  \
# 1                      Consumer price index (CPI)
# 5                      Consumer price index (CPI)
# ...
